# %%
import ibis
import ibis.expr.datatypes as dt
import json
con = ibis.connect("duckdb://")
con.list_tables()
# Out:
# []

# %%
con.attach_sqlite("Chinook_Sqlite.sqlite")
con.list_tables()
# Out:
# ['Album',
#  'Artist',
#  'Customer',
#  'Employee',
#  'Genre',
#  'Invoice',
#  'InvoiceLine',
#  'MediaType',
#  'Playlist',
#  'PlaylistTrack',
#  'Track']

# %%
tables = con.list_tables()
{table: con.table(table) for table in tables}
# Out:
# {'Album': DatabaseTable: Album
#    AlbumId  int64
#    Title    string
#    ArtistId int64,
#  'Artist': DatabaseTable: Artist
#    ArtistId int64
#    Name     string,
#  'Customer': DatabaseTable: Customer
#    CustomerId   int64
#    FirstName    string
#    LastName     string
#    Company      string
#    Address      string
#    City         string
#    State        string
#    Country      string
#    PostalCode   string
#    Phone        string
#    Fax          string
#    Email        string
#    SupportRepId int64,
#  'Employee': DatabaseTable: Employee
#    EmployeeId int64
#    LastName   string
#    FirstName  string
#    Title      string
#    ReportsTo  int64
#    BirthDate  timestamp(6)
#    HireDate   timestamp(6)
#    Address    string
#    City       string
#    State      string
#    Country    string
#    PostalCode string
#    Phone      string
#    Fax        string
#    Email      string,
#  'Genre': DatabaseTable: Genre
#    GenreId int64
#    Name    string,
#  'Invoice': DatabaseTable: Invoice
#    InvoiceId         int64
#    CustomerId        int64
#    InvoiceDate       timestamp(6)
#    BillingAddress    string
#    BillingCity       string
#    BillingState      string
#    BillingCountry    string
#    BillingPostalCode string
#    Total             float64,
#  'InvoiceLine': DatabaseTable: InvoiceLine
#    InvoiceLineId int64
#    InvoiceId     int64
#    TrackId       int64
#    UnitPrice     float64
#    Quantity      int64,
#  'MediaType': DatabaseTable: MediaType
#    MediaTypeId int64
#    Name        string,
#  'Playlist': DatabaseTable: Playlist
#    PlaylistId int64
#    Name       string,
#  'PlaylistTrack': DatabaseTable: PlaylistTrack
#    PlaylistId int64
#    TrackId    int64,
#  'Track': DatabaseTable: Track
#    TrackId      int64
#    Name         string
#    AlbumId      int64
#    MediaTypeId  int64
#    GenreId      int64
#    Composer     string
#    Milliseconds int64
#    Bytes        int64
#    UnitPrice    float64}

# %%
import ibis
import json

def gvq_to_ibis(json_data):
    # Convert JSON to tables and joins
    tables = [node['label'] for node in json_data['nodes']]
    joins = [{edge['label'].split(' = ')[0]: edge['label'].split(' = ')[1]} for edge in json_data['edges']]
    
    # Connect to the DuckDB database
    con = ibis.connect("duckdb://")
    con.attach_sqlite("Chinook_Sqlite.sqlite")
    print('list_table:', con.list_tables())
    
    # Load tables into Ibis
    ibis_tables = {table: con.table(table) for table in tables}

    # Initialize a dictionary to hold the renamed columns for each table
    renamed_columns = {table: {} for table in tables}
    
    # Rename columns to unique names
    for table in tables:
        rename_dict = {f"{table}_{col}": col for col in ibis_tables[table].columns}
        renamed_columns[table] = {col: f"{table}_{col}" for col in ibis_tables[table].columns}
        ibis_tables[table] = ibis_tables[table].rename(rename_dict)
        # Debugging: Print the renamed columns to verify
        print(f"Renamed columns for table {table}: {ibis_tables[table].columns}")

    # Update join conditions to use renamed columns
    updated_joins = []
    for join in joins:
        updated_join = {}
        for left_table_col, right_table_col in join.items():
            left_table, left_col = left_table_col.split('.')
            right_table, right_col = right_table_col.split('.')
            try:
                updated_join[f"{renamed_columns[left_table][left_col]}"] = f"{renamed_columns[right_table][right_col]}"
            except KeyError as e:
                print(f"KeyError: {e} in join condition {join}")
                continue
        updated_joins.append(updated_join)
        # Debugging: Print the updated join conditions
        print(f"Updated join: {updated_join}")

    # Initialize a variable to hold the join expression
    join_expr = None

    for idx, join in enumerate(updated_joins):
        if not join:
            print(f"Skipping empty join condition at index {idx}")
            continue
        left_table_col, right_table_col = list(join.items())[0]
        left_table = left_table_col.split('_')[0]
        right_table = right_table_col.split('_')[0]

        if idx == 0:
            # First join
            join_expr = ibis_tables[left_table].join(
                ibis_tables[right_table],
                ibis_tables[left_table][left_table_col] == ibis_tables[right_table][right_table_col],
                how='left'
            )
        else:
            # Subsequent joins using the previous join result
            join_expr = join_expr.join(
                ibis_tables[right_table],
                join_expr[left_table_col] == ibis_tables[right_table][right_table_col],
                how='left'
            )

    return join_expr

# %%
# Test Case 1
json_data1 = {
  "nodes": [
    { "id": "1", "label": "Album", "position": { "x": 100, "y": 100 } },
    { "id": "2", "label": "Artist", "position": { "x": 300, "y": 100 } }
  ],
  "edges": [
    { "source": "1", "target": "2", "label": "Album.ArtistId = Artist.ArtistId" }
  ]
}

json_data =json_data1

# Convert GVQ to Ibis expression
ibis_expr = gvq_to_ibis(json_data)
print(ibis_expr)

# Execute the Ibis expression and fetch results
result = ibis_expr.execute()
result
# Out:
# list_table: ['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track']
# Renamed columns for table Album: ['Album_AlbumId', 'Album_Title', 'Album_ArtistId']
# Renamed columns for table Artist: ['Artist_ArtistId', 'Artist_Name']
# Updated join: {'Album_ArtistId': 'Artist_ArtistId'}
# r0 := DatabaseTable: Album
#   AlbumId  int64
#   Title    string
#   ArtistId int64
#
# r1 := DatabaseTable: Artist
#   ArtistId int64
#   Name     string
#
# r2 := Project[r0]
#   Album_AlbumId:  r0.AlbumId
#   Album_Title:    r0.Title
#   Album_ArtistId: r0.ArtistId
#
# r3 := Project[r1]
#   Artist_ArtistId: r1.ArtistId
#   Artist_Name:     r1.Name
#
# JoinChain[r2]
#   JoinLink[left, r3]
#     r2.Album_ArtistId == r3.Artist_ArtistId
#   values:
#     Album_AlbumId:   r2.Album_AlbumId
#     Album_Title:     r2.Album_Title
#     Album_ArtistId:  r2.Album_ArtistId
#     Artist_ArtistId: r3.Artist_ArtistId
#     Artist_Name:     r3.Artist_Name
#      Album_AlbumId                               Album_Title  Album_ArtistId  \
# 0                1     For Those About To Rock We Salute You               1
# 1                2                         Balls to the Wall               2
# 2                3                         Restless and Wild               2
# 3                4                         Let There Be Rock               1
# 4                5                                  Big Ones               3
# ..             ...                                       ...             ...
# 342            325          Bartok: Violin & Viola Concertos             255
# 343            343                    Respighi:Pines of Rome             226
# 344            175                   Walking Into Clarksdale             115
# 345            253  Battlestar Galactica (Classic), Season 1             158
# 346            329                    South American Getaway             259
#
#      Artist_ArtistId                                 Artist_Name
# 0                  1                                       AC/DC
# 1                  2                                      Accept
# 2                  2                                      Accept
# 3                  1                                       AC/DC
# 4                  3                                   Aerosmith
# ..               ...                                         ...
# 342              255                              Yehudi Menuhin
# 343              226                              Eugene Ormandy
# 344              115                                Page & Plant
# 345              158              Battlestar Galactica (Classic)
# 346              259  The 12 Cellists of The Berlin Philharmonic
#
# [347 rows x 5 columns]

# %%
# Test Case 2
json_data2 = {
  "nodes": [
    { "id": "1", "label": "Invoice", "position": { "x": 100, "y": 100 } },
    { "id": "2", "label": "Customer", "position": { "x": 300, "y": 100 } },
    { "id": "3", "label": "Employee", "position": { "x": 500, "y": 100 } }
  ],
  "edges": [
    { "source": "1", "target": "2", "label": "Invoice.CustomerId = Customer.CustomerId" },
    { "source": "2", "target": "3", "label": "Customer.SupportRepId = Employee.EmployeeId" }
  ]
}

json_data =json_data2

# Convert GVQ to Ibis expression
ibis_expr = gvq_to_ibis(json_data)
print(ibis_expr)

# Execute the Ibis expression and fetch results
result = ibis_expr.execute()
result
# Out:
# list_table: ['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track']
# Renamed columns for table Invoice: ['Invoice_InvoiceId', 'Invoice_CustomerId', 'Invoice_InvoiceDate', 'Invoice_BillingAddress', 'Invoice_BillingCity', 'Invoice_BillingState', 'Invoice_BillingCountry', 'Invoice_BillingPostalCode', 'Invoice_Total']
# Renamed columns for table Customer: ['Customer_CustomerId', 'Customer_FirstName', 'Customer_LastName', 'Customer_Company', 'Customer_Address', 'Customer_City', 'Customer_State', 'Customer_Country', 'Customer_PostalCode', 'Customer_Phone', 'Customer_Fax', 'Customer_Email', 'Customer_SupportRepId']
# Renamed columns for table Employee: ['Employee_EmployeeId', 'Employee_LastName', 'Employee_FirstName', 'Employee_Title', 'Employee_ReportsTo', 'Employee_BirthDate', 'Employee_HireDate', 'Employee_Address', 'Employee_City', 'Employee_State', 'Employee_Country', 'Employee_PostalCode', 'Employee_Phone', 'Employee_Fax', 'Employee_Email']
# Updated join: {'Invoice_CustomerId': 'Customer_CustomerId'}
# Updated join: {'Customer_SupportRepId': 'Employee_EmployeeId'}
# r0 := DatabaseTable: Invoice
#   InvoiceId         int64
#   CustomerId        int64
#   InvoiceDate       timestamp(6)
#   BillingAddress    string
#   BillingCity       string
#   BillingState      string
#   BillingCountry    string
#   BillingPostalCode string
#   Total             float64
#
# r1 := DatabaseTable: Customer
#   CustomerId   int64
#   FirstName    string
#   LastName     string
#   Company      string
#   Address      string
#   City         string
#   State        string
#   Country      string
#   PostalCode   string
#   Phone        string
#   Fax          string
#   Email        string
#   SupportRepId int64
#
# r2 := DatabaseTable: Employee
#   EmployeeId int64
#   LastName   string
#   FirstName  string
#   Title      string
#   ReportsTo  int64
#   BirthDate  timestamp(6)
#   HireDate   timestamp(6)
#   Address    string
#   City       string
#   State      string
#   Country    string
#   PostalCode string
#   Phone      string
#   Fax        string
#   Email      string
#
# r3 := Project[r0]
#   Invoice_InvoiceId:         r0.InvoiceId
#   Invoice_CustomerId:        r0.CustomerId
#   Invoice_InvoiceDate:       r0.InvoiceDate
#   Invoice_BillingAddress:    r0.BillingAddress
#   Invoice_BillingCity:       r0.BillingCity
#   Invoice_BillingState:      r0.BillingState
#   Invoice_BillingCountry:    r0.BillingCountry
#   Invoice_BillingPostalCode: r0.BillingPostalCode
#   Invoice_Total:             r0.Total
#
# r4 := Project[r1]
#   Customer_CustomerId:   r1.CustomerId
#   Customer_FirstName:    r1.FirstName
#   Customer_LastName:     r1.LastName
#   Customer_Company:      r1.Company
#   Customer_Address:      r1.Address
#   Customer_City:         r1.City
#   Customer_State:        r1.State
#   Customer_Country:      r1.Country
#   Customer_PostalCode:   r1.PostalCode
#   Customer_Phone:        r1.Phone
#   Customer_Fax:          r1.Fax
#   Customer_Email:        r1.Email
#   Customer_SupportRepId: r1.SupportRepId
#
# r5 := Project[r2]
#   Employee_EmployeeId: r2.EmployeeId
#   Employee_LastName:   r2.LastName
#   Employee_FirstName:  r2.FirstName
#   Employee_Title:      r2.Title
#   Employee_ReportsTo:  r2.ReportsTo
#   Employee_BirthDate:  r2.BirthDate
#   Employee_HireDate:   r2.HireDate
#   Employee_Address:    r2.Address
#   Employee_City:       r2.City
#   Employee_State:      r2.State
#   Employee_Country:    r2.Country
#   Employee_PostalCode: r2.PostalCode
#   Employee_Phone:      r2.Phone
#   Employee_Fax:        r2.Fax
#   Employee_Email:      r2.Email
#
# JoinChain[r3]
#   JoinLink[left, r4]
#     r3.Invoice_CustomerId == r4.Customer_CustomerId
#   JoinLink[left, r5]
#     r4.Customer_SupportRepId == r5.Employee_EmployeeId
#   values:
#     Invoice_InvoiceId:         r3.Invoice_InvoiceId
#     Invoice_CustomerId:        r3.Invoice_CustomerId
#     Invoice_InvoiceDate:       r3.Invoice_InvoiceDate
#     Invoice_BillingAddress:    r3.Invoice_BillingAddress
#     Invoice_BillingCity:       r3.Invoice_BillingCity
#     Invoice_BillingState:      r3.Invoice_BillingState
#     Invoice_BillingCountry:    r3.Invoice_BillingCountry
#     Invoice_BillingPostalCode: r3.Invoice_BillingPostalCode
#     Invoice_Total:             r3.Invoice_Total
#     Customer_CustomerId:       r4.Customer_CustomerId
#     Customer_FirstName:        r4.Customer_FirstName
#     Customer_LastName:         r4.Customer_LastName
#     Customer_Company:          r4.Customer_Company
#     Customer_Address:          r4.Customer_Address
#     Customer_City:             r4.Customer_City
#     Customer_State:            r4.Customer_State
#     Customer_Country:          r4.Customer_Country
#     Customer_PostalCode:       r4.Customer_PostalCode
#     Customer_Phone:            r4.Customer_Phone
#     Customer_Fax:              r4.Customer_Fax
#     Customer_Email:            r4.Customer_Email
#     Customer_SupportRepId:     r4.Customer_SupportRepId
#     Employee_EmployeeId:       r5.Employee_EmployeeId
#     Employee_LastName:         r5.Employee_LastName
#     Employee_FirstName:        r5.Employee_FirstName
#     Employee_Title:            r5.Employee_Title
#     Employee_ReportsTo:        r5.Employee_ReportsTo
#     Employee_BirthDate:        r5.Employee_BirthDate
#     Employee_HireDate:         r5.Employee_HireDate
#     Employee_Address:          r5.Employee_Address
#     Employee_City:             r5.Employee_City
#     Employee_State:            r5.Employee_State
#     Employee_Country:          r5.Employee_Country
#     Employee_PostalCode:       r5.Employee_PostalCode
#     Employee_Phone:            r5.Employee_Phone
#     Employee_Fax:              r5.Employee_Fax
#     Employee_Email:            r5.Employee_Email
#      Invoice_InvoiceId  Invoice_CustomerId Invoice_InvoiceDate  \
# 0                    1                   2          2009-01-01
# 1                    2                   4          2009-01-02
# 2                    3                   8          2009-01-03
# 3                    4                  14          2009-01-06
# 4                    5                  23          2009-01-11
# ..                 ...                 ...                 ...
# 407                357                  50          2013-05-01
# 408                380                  50          2013-08-03
# 409                400                  44          2013-11-03
# 410                402                  50          2013-11-05
# 411                411                  44          2013-12-14
#
#       Invoice_BillingAddress Invoice_BillingCity Invoice_BillingState  \
# 0    Theodor-Heuss-Straße 34           Stuttgart                 None
# 1           Ullevålsveien 14                Oslo                 None
# 2            Grétrystraat 63            Brussels                 None
# 3             8210 111 ST NW            Edmonton                   AB
# 4            69 Salem Street              Boston                   MA
# ..                       ...                 ...                  ...
# 407       C/ San Bernardo 85              Madrid                 None
# 408       C/ San Bernardo 85              Madrid                 None
# 409          Porthaninkatu 9            Helsinki                 None
# 410       C/ San Bernardo 85              Madrid                 None
# 411          Porthaninkatu 9            Helsinki                 None
#
#     Invoice_BillingCountry Invoice_BillingPostalCode  Invoice_Total  \
# 0                  Germany                     70174           1.98
# 1                   Norway                      0171           3.96
# 2                  Belgium                      1000           5.94
# 3                   Canada                   T6G 2C7           8.91
# 4                      USA                      2113          13.86
# ..                     ...                       ...            ...
# 407                  Spain                     28015           1.98
# 408                  Spain                     28015           3.96
# 409                Finland                     00530           1.98
# 410                  Spain                     28015           5.94
# 411                Finland                     00530          13.86
#
#      Customer_CustomerId  ... Employee_BirthDate Employee_HireDate  \
# 0                      2  ...         1965-03-03        2003-10-17
# 1                      4  ...         1947-09-19        2003-05-03
# 2                      8  ...         1947-09-19        2003-05-03
# 3                     14  ...         1965-03-03        2003-10-17
# 4                     23  ...         1947-09-19        2003-05-03
# ..                   ...  ...                ...               ...
# 407                   50  ...         1965-03-03        2003-10-17
# 408                   50  ...         1965-03-03        2003-10-17
# 409                   44  ...         1973-08-29        2002-04-01
# 410                   50  ...         1965-03-03        2003-10-17
# 411                   44  ...         1973-08-29        2002-04-01
#
#      Employee_Address Employee_City Employee_State Employee_Country  \
# 0        7727B 41 Ave       Calgary             AB           Canada
# 1    683 10 Street SW       Calgary             AB           Canada
# 2    683 10 Street SW       Calgary             AB           Canada
# 3        7727B 41 Ave       Calgary             AB           Canada
# 4    683 10 Street SW       Calgary             AB           Canada
# ..                ...           ...            ...              ...
# 407      7727B 41 Ave       Calgary             AB           Canada
# 408      7727B 41 Ave       Calgary             AB           Canada
# 409     1111 6 Ave SW       Calgary             AB           Canada
# 410      7727B 41 Ave       Calgary             AB           Canada
# 411     1111 6 Ave SW       Calgary             AB           Canada
#
#     Employee_PostalCode     Employee_Phone       Employee_Fax  \
# 0               T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
# 1               T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 2               T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 3               T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
# 4               T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# ..                  ...                ...                ...
# 407             T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
# 408             T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
# 409             T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 410             T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
# 411             T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
#
#                Employee_Email
# 0       steve@chinookcorp.com
# 1    margaret@chinookcorp.com
# 2    margaret@chinookcorp.com
# 3       steve@chinookcorp.com
# 4    margaret@chinookcorp.com
# ..                        ...
# 407     steve@chinookcorp.com
# 408     steve@chinookcorp.com
# 409      jane@chinookcorp.com
# 410     steve@chinookcorp.com
# 411      jane@chinookcorp.com
#
# [412 rows x 37 columns]

# %%
# Test Case 3
json_data3 = {
  "nodes": [
    { "id": "1", "label": "InvoiceLine", "position": { "x": 100, "y": 100 } },
    { "id": "2", "label": "Invoice", "position": { "x": 300, "y": 100 } },
    { "id": "3", "label": "Track", "position": { "x": 500, "y": 100 } },
    { "id": "4", "label": "Album", "position": { "x": 700, "y": 100 } }
  ],
  "edges": [
    { "source": "1", "target": "2", "label": "InvoiceLine.InvoiceId = Invoice.InvoiceId" },
    { "source": "1", "target": "3", "label": "InvoiceLine.TrackId = Track.TrackId" },
    { "source": "3", "target": "4", "label": "Track.AlbumId = Album.AlbumId" }
  ]
}

json_data =json_data3

# Convert GVQ to Ibis expression
ibis_expr = gvq_to_ibis(json_data)
print(ibis_expr)

# Execute the Ibis expression and fetch results
result = ibis_expr.execute()
result
# Out:
# list_table: ['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track']
# Renamed columns for table InvoiceLine: ['InvoiceLine_InvoiceLineId', 'InvoiceLine_InvoiceId', 'InvoiceLine_TrackId', 'InvoiceLine_UnitPrice', 'InvoiceLine_Quantity']
# Renamed columns for table Invoice: ['Invoice_InvoiceId', 'Invoice_CustomerId', 'Invoice_InvoiceDate', 'Invoice_BillingAddress', 'Invoice_BillingCity', 'Invoice_BillingState', 'Invoice_BillingCountry', 'Invoice_BillingPostalCode', 'Invoice_Total']
# Renamed columns for table Track: ['Track_TrackId', 'Track_Name', 'Track_AlbumId', 'Track_MediaTypeId', 'Track_GenreId', 'Track_Composer', 'Track_Milliseconds', 'Track_Bytes', 'Track_UnitPrice']
# Renamed columns for table Album: ['Album_AlbumId', 'Album_Title', 'Album_ArtistId']
# Updated join: {'InvoiceLine_InvoiceId': 'Invoice_InvoiceId'}
# Updated join: {'InvoiceLine_TrackId': 'Track_TrackId'}
# Updated join: {'Track_AlbumId': 'Album_AlbumId'}
# r0 := DatabaseTable: InvoiceLine
#   InvoiceLineId int64
#   InvoiceId     int64
#   TrackId       int64
#   UnitPrice     float64
#   Quantity      int64
#
# r1 := DatabaseTable: Invoice
#   InvoiceId         int64
#   CustomerId        int64
#   InvoiceDate       timestamp(6)
#   BillingAddress    string
#   BillingCity       string
#   BillingState      string
#   BillingCountry    string
#   BillingPostalCode string
#   Total             float64
#
# r2 := DatabaseTable: Track
#   TrackId      int64
#   Name         string
#   AlbumId      int64
#   MediaTypeId  int64
#   GenreId      int64
#   Composer     string
#   Milliseconds int64
#   Bytes        int64
#   UnitPrice    float64
#
# r3 := DatabaseTable: Album
#   AlbumId  int64
#   Title    string
#   ArtistId int64
#
# r4 := Project[r0]
#   InvoiceLine_InvoiceLineId: r0.InvoiceLineId
#   InvoiceLine_InvoiceId:     r0.InvoiceId
#   InvoiceLine_TrackId:       r0.TrackId
#   InvoiceLine_UnitPrice:     r0.UnitPrice
#   InvoiceLine_Quantity:      r0.Quantity
#
# r5 := Project[r1]
#   Invoice_InvoiceId:         r1.InvoiceId
#   Invoice_CustomerId:        r1.CustomerId
#   Invoice_InvoiceDate:       r1.InvoiceDate
#   Invoice_BillingAddress:    r1.BillingAddress
#   Invoice_BillingCity:       r1.BillingCity
#   Invoice_BillingState:      r1.BillingState
#   Invoice_BillingCountry:    r1.BillingCountry
#   Invoice_BillingPostalCode: r1.BillingPostalCode
#   Invoice_Total:             r1.Total
#
# r6 := Project[r2]
#   Track_TrackId:      r2.TrackId
#   Track_Name:         r2.Name
#   Track_AlbumId:      r2.AlbumId
#   Track_MediaTypeId:  r2.MediaTypeId
#   Track_GenreId:      r2.GenreId
#   Track_Composer:     r2.Composer
#   Track_Milliseconds: r2.Milliseconds
#   Track_Bytes:        r2.Bytes
#   Track_UnitPrice:    r2.UnitPrice
#
# r7 := Project[r3]
#   Album_AlbumId:  r3.AlbumId
#   Album_Title:    r3.Title
#   Album_ArtistId: r3.ArtistId
#
# JoinChain[r4]
#   JoinLink[left, r5]
#     r4.InvoiceLine_InvoiceId == r5.Invoice_InvoiceId
#   JoinLink[left, r6]
#     r4.InvoiceLine_TrackId == r6.Track_TrackId
#   JoinLink[left, r7]
#     r6.Track_AlbumId == r7.Album_AlbumId
#   values:
#     InvoiceLine_InvoiceLineId: r4.InvoiceLine_InvoiceLineId
#     InvoiceLine_InvoiceId:     r4.InvoiceLine_InvoiceId
#     InvoiceLine_TrackId:       r4.InvoiceLine_TrackId
#     InvoiceLine_UnitPrice:     r4.InvoiceLine_UnitPrice
#     InvoiceLine_Quantity:      r4.InvoiceLine_Quantity
#     Invoice_InvoiceId:         r5.Invoice_InvoiceId
#     Invoice_CustomerId:        r5.Invoice_CustomerId
#     Invoice_InvoiceDate:       r5.Invoice_InvoiceDate
#     Invoice_BillingAddress:    r5.Invoice_BillingAddress
#     Invoice_BillingCity:       r5.Invoice_BillingCity
#     Invoice_BillingState:      r5.Invoice_BillingState
#     Invoice_BillingCountry:    r5.Invoice_BillingCountry
#     Invoice_BillingPostalCode: r5.Invoice_BillingPostalCode
#     Invoice_Total:             r5.Invoice_Total
#     Track_TrackId:             r6.Track_TrackId
#     Track_Name:                r6.Track_Name
#     Track_AlbumId:             r6.Track_AlbumId
#     Track_MediaTypeId:         r6.Track_MediaTypeId
#     Track_GenreId:             r6.Track_GenreId
#     Track_Composer:            r6.Track_Composer
#     Track_Milliseconds:        r6.Track_Milliseconds
#     Track_Bytes:               r6.Track_Bytes
#     Track_UnitPrice:           r6.Track_UnitPrice
#     Album_AlbumId:             r7.Album_AlbumId
#     Album_Title:               r7.Album_Title
#     Album_ArtistId:            r7.Album_ArtistId
#       InvoiceLine_InvoiceLineId  InvoiceLine_InvoiceId  InvoiceLine_TrackId  \
# 0                             1                      1                    2
# 1                             2                      1                    4
# 2                             3                      2                    6
# 3                             4                      2                    8
# 4                             6                      2                   12
# ...                         ...                    ...                  ...
# 2235                        730                    136                  925
# 2236                       1125                    208                 3333
# 2237                       1697                    313                 3328
# 2238                       1879                    347                  925
# 2239                        732                    136                  933
#
#       InvoiceLine_UnitPrice  InvoiceLine_Quantity  Invoice_InvoiceId  \
# 0                      0.99                     1                  1
# 1                      0.99                     1                  1
# 2                      0.99                     1                  2
# 3                      0.99                     1                  2
# 4                      0.99                     1                  2
# ...                     ...                   ...                ...
# 2235                   0.99                     1                136
# 2236                   0.99                     1                208
# 2237                   0.99                     1                313
# 2238                   0.99                     1                347
# 2239                   0.99                     1                136
#
#       Invoice_CustomerId Invoice_InvoiceDate   Invoice_BillingAddress  \
# 0                      2          2009-01-01  Theodor-Heuss-Straße 34
# 1                      2          2009-01-01  Theodor-Heuss-Straße 34
# 2                      4          2009-01-02         Ullevålsveien 14
# 3                      4          2009-01-02         Ullevålsveien 14
# 4                      4          2009-01-02         Ullevålsveien 14
# ...                  ...                 ...                      ...
# 2235                  22          2010-08-15         120 S Orange Ave
# 2236                   4          2011-06-29         Ullevålsveien 14
# 2237                  43          2012-10-06         68, Rue Jouvence
# 2238                  47          2013-03-05   Via Degli Scipioni, 43
# 2239                  22          2010-08-15         120 S Orange Ave
#
#      Invoice_BillingCity  ... Track_AlbumId Track_MediaTypeId Track_GenreId  \
# 0              Stuttgart  ...             2                 2             1
# 1              Stuttgart  ...             3                 2             1
# 2                   Oslo  ...             1                 1             1
# 3                   Oslo  ...             1                 1             1
# 4                   Oslo  ...             1                 1             1
# ...                  ...  ...           ...               ...           ...
# 2235             Orlando  ...            74                 1             4
# 2236                Oslo  ...           259                 1            15
# 2237               Dijon  ...           259                 1            15
# 2238                Rome  ...            74                 1             4
# 2239             Orlando  ...            74                 1             4
#
#                                          Track_Composer  Track_Milliseconds  \
# 0                                                  None              342562
# 1     F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...              252051
# 2             Angus Young, Malcolm Young, Brian Johnson              205662
# 3             Angus Young, Malcolm Young, Brian Johnson              210834
# 4             Angus Young, Malcolm Young, Brian Johnson              263288
# ...                                                 ...                 ...
# 2235                             Bill Gould/Mike Patton              251663
# 2236                                               None              221805
# 2237                                               None              232881
# 2238                             Bill Gould/Mike Patton              251663
# 2239                                        Mike Patton              119040
#
#      Track_Bytes  Track_UnitPrice  Album_AlbumId  \
# 0        5510424             0.99              2
# 1        4331779             0.99              3
# 2        6713451             0.99              1
# 3        6852860             0.99              1
# 4        8596840             0.99              1
# ...          ...              ...            ...
# 2235     8221247             0.99             74
# 2236     8874509             0.99            259
# 2237     9317533             0.99            259
# 2238     8221247             0.99             74
# 2239     3898976             0.99             74
#
#                                             Album_Title Album_ArtistId
# 0                                     Balls to the Wall              2
# 1                                     Restless and Wild              2
# 2                 For Those About To Rock We Salute You              1
# 3                 For Those About To Rock We Salute You              1
# 4                 For Those About To Rock We Salute You              1
# ...                                                 ...            ...
# 2235                                  Album Of The Year             82
# 2236  Radio Brasil (O Som da Jovem Vanguarda) - Sele...             36
# 2237  Radio Brasil (O Som da Jovem Vanguarda) - Sele...             36
# 2238                                  Album Of The Year             82
# 2239                                  Album Of The Year             82
#
# [2240 rows x 26 columns]

# %%
# Example usage:
# Test Case 4
json_data4 = {
  "nodes": [
    { "id": "1", "label": "Track", "position": { "x": 100, "y": 100 } },
    { "id": "2", "label": "Genre", "position": { "x": 300, "y": 100 } },
    { "id": "3", "label": "MediaType", "position": { "x": 500, "y": 100 } }
  ],
  "edges": [
    { "source": "1", "target": "2", "label": "Track.GenreId = Genre.GenreId" },
    { "source": "1", "target": "3", "label": "Track.MediaTypeId = MediaType.MediaTypeId" }
  ]
}

json_data =json_data4

# Convert GVQ to Ibis expression
ibis_expr = gvq_to_ibis(json_data)
print(ibis_expr)

# Execute the Ibis expression and fetch results
result = ibis_expr.execute()
result
# Out:
# list_table: ['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track']
# Renamed columns for table Track: ['Track_TrackId', 'Track_Name', 'Track_AlbumId', 'Track_MediaTypeId', 'Track_GenreId', 'Track_Composer', 'Track_Milliseconds', 'Track_Bytes', 'Track_UnitPrice']
# Renamed columns for table Genre: ['Genre_GenreId', 'Genre_Name']
# Renamed columns for table MediaType: ['MediaType_MediaTypeId', 'MediaType_Name']
# Updated join: {'Track_GenreId': 'Genre_GenreId'}
# Updated join: {'Track_MediaTypeId': 'MediaType_MediaTypeId'}
# r0 := DatabaseTable: Track
#   TrackId      int64
#   Name         string
#   AlbumId      int64
#   MediaTypeId  int64
#   GenreId      int64
#   Composer     string
#   Milliseconds int64
#   Bytes        int64
#   UnitPrice    float64
#
# r1 := DatabaseTable: Genre
#   GenreId int64
#   Name    string
#
# r2 := DatabaseTable: MediaType
#   MediaTypeId int64
#   Name        string
#
# r3 := Project[r0]
#   Track_TrackId:      r0.TrackId
#   Track_Name:         r0.Name
#   Track_AlbumId:      r0.AlbumId
#   Track_MediaTypeId:  r0.MediaTypeId
#   Track_GenreId:      r0.GenreId
#   Track_Composer:     r0.Composer
#   Track_Milliseconds: r0.Milliseconds
#   Track_Bytes:        r0.Bytes
#   Track_UnitPrice:    r0.UnitPrice
#
# r4 := Project[r1]
#   Genre_GenreId: r1.GenreId
#   Genre_Name:    r1.Name
#
# r5 := Project[r2]
#   MediaType_MediaTypeId: r2.MediaTypeId
#   MediaType_Name:        r2.Name
#
# JoinChain[r3]
#   JoinLink[left, r4]
#     r3.Track_GenreId == r4.Genre_GenreId
#   JoinLink[left, r5]
#     r3.Track_MediaTypeId == r5.MediaType_MediaTypeId
#   values:
#     Track_TrackId:         r3.Track_TrackId
#     Track_Name:            r3.Track_Name
#     Track_AlbumId:         r3.Track_AlbumId
#     Track_MediaTypeId:     r3.Track_MediaTypeId
#     Track_GenreId:         r3.Track_GenreId
#     Track_Composer:        r3.Track_Composer
#     Track_Milliseconds:    r3.Track_Milliseconds
#     Track_Bytes:           r3.Track_Bytes
#     Track_UnitPrice:       r3.Track_UnitPrice
#     Genre_GenreId:         r4.Genre_GenreId
#     Genre_Name:            r4.Genre_Name
#     MediaType_MediaTypeId: r5.MediaType_MediaTypeId
#     MediaType_Name:        r5.MediaType_Name
#       Track_TrackId                                         Track_Name  \
# 0                 1            For Those About To Rock (We Salute You)
# 1                 2                                  Balls to the Wall
# 2                 3                                    Fast As a Shark
# 3                 4                                  Restless and Wild
# 4                 5                               Princess of the Dawn
# ...             ...                                                ...
# 3498           3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...
# 3499           3500  String Quartet No. 12 in C Minor, D. 703 "Quar...
# 3500           3501               L'orfeo, Act 3, Sinfonia (Orchestra)
# 3501           3502  Quintet for Horn, Violin, 2 Violas, and Cello ...
# 3502           3503                                      Koyaanisqatsi
#
#       Track_AlbumId  Track_MediaTypeId  Track_GenreId  \
# 0                 1                  1              1
# 1                 2                  2              1
# 2                 3                  2              1
# 3                 3                  2              1
# 4                 3                  2              1
# ...             ...                ...            ...
# 3498            343                  2             24
# 3499            344                  2             24
# 3500            345                  2             24
# 3501            346                  2             24
# 3502            347                  2             10
#
#                                          Track_Composer  Track_Milliseconds  \
# 0             Angus Young, Malcolm Young, Brian Johnson              343719
# 1                                                  None              342562
# 2     F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...              230619
# 3     F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...              252051
# 4                            Deaffy & R.A. Smith-Diesel              375418
# ...                                                 ...                 ...
# 3498                                               None              286741
# 3499                                     Franz Schubert              139200
# 3500                                 Claudio Monteverdi               66639
# 3501                            Wolfgang Amadeus Mozart              221331
# 3502                                       Philip Glass              206005
#
#       Track_Bytes  Track_UnitPrice  Genre_GenreId  Genre_Name  \
# 0        11170334             0.99              1        Rock
# 1         5510424             0.99              1        Rock
# 2         3990994             0.99              1        Rock
# 3         4331779             0.99              1        Rock
# 4         6290521             0.99              1        Rock
# ...           ...              ...            ...         ...
# 3498      4718950             0.99             24   Classical
# 3499      2283131             0.99             24   Classical
# 3500      1189062             0.99             24   Classical
# 3501      3665114             0.99             24   Classical
# 3502      3305164             0.99             10  Soundtrack
#
#       MediaType_MediaTypeId            MediaType_Name
# 0                         1           MPEG audio file
# 1                         2  Protected AAC audio file
# 2                         2  Protected AAC audio file
# 3                         2  Protected AAC audio file
# 4                         2  Protected AAC audio file
# ...                     ...                       ...
# 3498                      2  Protected AAC audio file
# 3499                      2  Protected AAC audio file
# 3500                      2  Protected AAC audio file
# 3501                      2  Protected AAC audio file
# 3502                      2  Protected AAC audio file
#
# [3503 rows x 13 columns]

# %%
# Test Case 5
json_data5 = {
  "nodes": [
    { "id": "1", "label": "Customer", "position": { "x": 100, "y": 100 } },
    { "id": "2", "label": "Invoice", "position": { "x": 300, "y": 100 } },
    { "id": "3", "label": "Employee", "position": { "x": 500, "y": 100 } },
    { "id": "4", "label": "Employee", "position": { "x": 700, "y": 100 } }  # Changed from 'Support' to 'Employee'
  ],
  "edges": [
    { "source": "1", "target": "2", "label": "Customer.CustomerId = Invoice.CustomerId" },
    { "source": "2", "target": "3", "label": "Invoice.SupportRepId = Employee.EmployeeId" },
    { "source": "1", "target": "4", "label": "Customer.SupportRepId = Employee.SupportRepId" }  # Adjusted the column names accordingly
  ]
}

json_data = json_data5

# Convert GVQ to Ibis expression
ibis_expr = gvq_to_ibis(json_data)
print(ibis_expr)

# Execute the Ibis expression and fetch results
result = ibis_expr.execute()
result
# Out:
# list_table: ['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track']
# Renamed columns for table Customer: ['Customer_CustomerId', 'Customer_FirstName', 'Customer_LastName', 'Customer_Company', 'Customer_Address', 'Customer_City', 'Customer_State', 'Customer_Country', 'Customer_PostalCode', 'Customer_Phone', 'Customer_Fax', 'Customer_Email', 'Customer_SupportRepId']
# Renamed columns for table Invoice: ['Invoice_InvoiceId', 'Invoice_CustomerId', 'Invoice_InvoiceDate', 'Invoice_BillingAddress', 'Invoice_BillingCity', 'Invoice_BillingState', 'Invoice_BillingCountry', 'Invoice_BillingPostalCode', 'Invoice_Total']
# Renamed columns for table Employee: ['Employee_EmployeeId', 'Employee_LastName', 'Employee_FirstName', 'Employee_Title', 'Employee_ReportsTo', 'Employee_BirthDate', 'Employee_HireDate', 'Employee_Address', 'Employee_City', 'Employee_State', 'Employee_Country', 'Employee_PostalCode', 'Employee_Phone', 'Employee_Fax', 'Employee_Email']
# Renamed columns for table Employee: ['Employee_Employee_EmployeeId', 'Employee_Employee_LastName', 'Employee_Employee_FirstName', 'Employee_Employee_Title', 'Employee_Employee_ReportsTo', 'Employee_Employee_BirthDate', 'Employee_Employee_HireDate', 'Employee_Employee_Address', 'Employee_Employee_City', 'Employee_Employee_State', 'Employee_Employee_Country', 'Employee_Employee_PostalCode', 'Employee_Employee_Phone', 'Employee_Employee_Fax', 'Employee_Employee_Email']
# Updated join: {'Customer_CustomerId': 'Invoice_CustomerId'}
# KeyError: 'EmployeeId' in join condition {'Invoice.SupportRepId': 'Employee.EmployeeId'}
# Updated join: {}
# KeyError: 'SupportRepId' in join condition {'Customer.SupportRepId': 'Employee.SupportRepId'}
# Updated join: {}
# Skipping empty join condition at index 1
# Skipping empty join condition at index 2
# r0 := DatabaseTable: Customer
#   CustomerId   int64
#   FirstName    string
#   LastName     string
#   Company      string
#   Address      string
#   City         string
#   State        string
#   Country      string
#   PostalCode   string
#   Phone        string
#   Fax          string
#   Email        string
#   SupportRepId int64
#
# r1 := DatabaseTable: Invoice
#   InvoiceId         int64
#   CustomerId        int64
#   InvoiceDate       timestamp(6)
#   BillingAddress    string
#   BillingCity       string
#   BillingState      string
#   BillingCountry    string
#   BillingPostalCode string
#   Total             float64
#
# r2 := Project[r0]
#   Customer_CustomerId:   r0.CustomerId
#   Customer_FirstName:    r0.FirstName
#   Customer_LastName:     r0.LastName
#   Customer_Company:      r0.Company
#   Customer_Address:      r0.Address
#   Customer_City:         r0.City
#   Customer_State:        r0.State
#   Customer_Country:      r0.Country
#   Customer_PostalCode:   r0.PostalCode
#   Customer_Phone:        r0.Phone
#   Customer_Fax:          r0.Fax
#   Customer_Email:        r0.Email
#   Customer_SupportRepId: r0.SupportRepId
#
# r3 := Project[r1]
#   Invoice_InvoiceId:         r1.InvoiceId
#   Invoice_CustomerId:        r1.CustomerId
#   Invoice_InvoiceDate:       r1.InvoiceDate
#   Invoice_BillingAddress:    r1.BillingAddress
#   Invoice_BillingCity:       r1.BillingCity
#   Invoice_BillingState:      r1.BillingState
#   Invoice_BillingCountry:    r1.BillingCountry
#   Invoice_BillingPostalCode: r1.BillingPostalCode
#   Invoice_Total:             r1.Total
#
# JoinChain[r2]
#   JoinLink[left, r3]
#     r2.Customer_CustomerId == r3.Invoice_CustomerId
#   values:
#     Customer_CustomerId:       r2.Customer_CustomerId
#     Customer_FirstName:        r2.Customer_FirstName
#     Customer_LastName:         r2.Customer_LastName
#     Customer_Company:          r2.Customer_Company
#     Customer_Address:          r2.Customer_Address
#     Customer_City:             r2.Customer_City
#     Customer_State:            r2.Customer_State
#     Customer_Country:          r2.Customer_Country
#     Customer_PostalCode:       r2.Customer_PostalCode
#     Customer_Phone:            r2.Customer_Phone
#     Customer_Fax:              r2.Customer_Fax
#     Customer_Email:            r2.Customer_Email
#     Customer_SupportRepId:     r2.Customer_SupportRepId
#     Invoice_InvoiceId:         r3.Invoice_InvoiceId
#     Invoice_CustomerId:        r3.Invoice_CustomerId
#     Invoice_InvoiceDate:       r3.Invoice_InvoiceDate
#     Invoice_BillingAddress:    r3.Invoice_BillingAddress
#     Invoice_BillingCity:       r3.Invoice_BillingCity
#     Invoice_BillingState:      r3.Invoice_BillingState
#     Invoice_BillingCountry:    r3.Invoice_BillingCountry
#     Invoice_BillingPostalCode: r3.Invoice_BillingPostalCode
#     Invoice_Total:             r3.Invoice_Total
#      Customer_CustomerId Customer_FirstName Customer_LastName  \
# 0                      2             Leonie            Köhler
# 1                      4              Bjørn            Hansen
# 2                      8               Daan           Peeters
# 3                     14               Mark           Philips
# 4                     23               John            Gordon
# ..                   ...                ...               ...
# 407                   50            Enrique             Muñoz
# 408                   50            Enrique             Muñoz
# 409                   44              Terhi        Hämäläinen
# 410                   50            Enrique             Muñoz
# 411                   44              Terhi        Hämäläinen
#
#     Customer_Company         Customer_Address Customer_City Customer_State  \
# 0               None  Theodor-Heuss-Straße 34     Stuttgart           None
# 1               None         Ullevålsveien 14          Oslo           None
# 2               None          Grétrystraat 63      Brussels           None
# 3              Telus           8210 111 ST NW      Edmonton             AB
# 4               None          69 Salem Street        Boston             MA
# ..               ...                      ...           ...            ...
# 407             None       C/ San Bernardo 85        Madrid           None
# 408             None       C/ San Bernardo 85        Madrid           None
# 409             None          Porthaninkatu 9      Helsinki           None
# 410             None       C/ San Bernardo 85        Madrid           None
# 411             None          Porthaninkatu 9      Helsinki           None
#
#     Customer_Country Customer_PostalCode     Customer_Phone  ...  \
# 0            Germany               70174   +49 0711 2842222  ...
# 1             Norway                0171    +47 22 44 22 22  ...
# 2            Belgium                1000   +32 02 219 03 03  ...
# 3             Canada             T6G 2C7  +1 (780) 434-4554  ...
# 4                USA                2113  +1 (617) 522-1333  ...
# ..               ...                 ...                ...  ...
# 407            Spain               28015    +34 914 454 454  ...
# 408            Spain               28015    +34 914 454 454  ...
# 409          Finland               00530   +358 09 870 2000  ...
# 410            Spain               28015    +34 914 454 454  ...
# 411          Finland               00530   +358 09 870 2000  ...
#
#     Customer_SupportRepId Invoice_InvoiceId  Invoice_CustomerId  \
# 0                       5                 1                   2
# 1                       4                 2                   4
# 2                       4                 3                   8
# 3                       5                 4                  14
# 4                       4                 5                  23
# ..                    ...               ...                 ...
# 407                     5               357                  50
# 408                     5               380                  50
# 409                     3               400                  44
# 410                     5               402                  50
# 411                     3               411                  44
#
#      Invoice_InvoiceDate   Invoice_BillingAddress Invoice_BillingCity  \
# 0             2009-01-01  Theodor-Heuss-Straße 34           Stuttgart
# 1             2009-01-02         Ullevålsveien 14                Oslo
# 2             2009-01-03          Grétrystraat 63            Brussels
# 3             2009-01-06           8210 111 ST NW            Edmonton
# 4             2009-01-11          69 Salem Street              Boston
# ..                   ...                      ...                 ...
# 407           2013-05-01       C/ San Bernardo 85              Madrid
# 408           2013-08-03       C/ San Bernardo 85              Madrid
# 409           2013-11-03          Porthaninkatu 9            Helsinki
# 410           2013-11-05       C/ San Bernardo 85              Madrid
# 411           2013-12-14          Porthaninkatu 9            Helsinki
#
#     Invoice_BillingState Invoice_BillingCountry Invoice_BillingPostalCode  \
# 0                   None                Germany                     70174
# 1                   None                 Norway                      0171
# 2                   None                Belgium                      1000
# 3                     AB                 Canada                   T6G 2C7
# 4                     MA                    USA                      2113
# ..                   ...                    ...                       ...
# 407                 None                  Spain                     28015
# 408                 None                  Spain                     28015
# 409                 None                Finland                     00530
# 410                 None                  Spain                     28015
# 411                 None                Finland                     00530
#
#     Invoice_Total
# 0            1.98
# 1            3.96
# 2            5.94
# 3            8.91
# 4           13.86
# ..            ...
# 407          1.98
# 408          3.96
# 409          1.98
# 410          5.94
# 411         13.86
#
# [412 rows x 22 columns]
