# %%
import ibis
from collections import defaultdict, deque

def join_sort(joins):
    # Create a graph to represent dependencies between tables
    graph = defaultdict(list)
    indegree = defaultdict(int)

    # Build the graph and compute indegree
    for join in joins:
        for left_table_col, right_table_col in join.items():
            left_table, left_col = left_table_col.split('.')
            right_table, right_col = right_table_col.split('.')
            graph[left_table].append((right_table, join))
            indegree[right_table] += 1
            if left_table not in indegree:
                indegree[left_table] = 0

    # Use a deque to perform stable topological sorting
    queue = deque(sorted([table for table in indegree if indegree[table] == 0]))
    sorted_joins = []

    while queue:
        table = queue.popleft()
        for neighbor, join in sorted(graph[table], key=lambda x: x[0]):
            sorted_joins.append(join)
            indegree[neighbor] -= 1
            if indegree[neighbor] == 0:
                queue.append(neighbor)
                queue = deque(sorted(queue))  # Maintain stable order

    return sorted_joins

def gvq_to_ibis(json_data):
    # Convert JSON to tables and joins
    tables = [node['label'] for node in json_data['nodes']]
    joins = [{edge['label'].split(' = ')[0]: edge['label'].split(' = ')[1]} for edge in json_data['edges']]
    print('>>joins:', joins)
    
    # Sort the joins based on dependencies
    sorted_joins = join_sort(joins)
    print('>>sorted_joins:', sorted_joins)
    
    # Connect to the DuckDB database
    con = ibis.connect("duckdb://")
    con.attach_sqlite("Chinook_Sqlite.sqlite")
    print('list_table:', con.list_tables())
    
    # Load tables into Ibis
    ibis_tables = {table: con.table(table) for table in tables}

    # Initialize a dictionary to hold the renamed columns for each table
    renamed_columns = {table: {} for table in tables}
    
    # Rename columns to unique names
    for table in tables:
        rename_dict = {f"{table}_{col}": col for col in ibis_tables[table].columns}
        renamed_columns[table] = {col: f"{table}_{col}" for col in ibis_tables[table].columns}
        ibis_tables[table] = ibis_tables[table].rename(rename_dict)
        # Debugging: Print the renamed columns to verify
        print(f"Renamed columns for table {table}: {ibis_tables[table].columns}")

    # Update join conditions to use renamed columns
    updated_joins = []
    for join in sorted_joins:
        updated_join = {}
        for left_table_col, right_table_col in join.items():
            left_table, left_col = left_table_col.split('.')
            right_table, right_col = right_table_col.split('.')
            try:
                updated_join[f"{renamed_columns[left_table][left_col]}"] = f"{renamed_columns[right_table][right_col]}"
            except KeyError as e:
                print(f"KeyError: {e} in join condition {join}")
                continue
        if updated_join:
            updated_joins.append(updated_join)
        # Debugging: Print the updated join conditions
        print(f"Updated join: {updated_join}")

    # Initialize a variable to hold the join expression
    join_expr = None

    for idx, join in enumerate(updated_joins):
        left_table_col, right_table_col = list(join.items())[0]
        left_table = left_table_col.split('_')[0]
        right_table = right_table_col.split('_')[0]

        if join_expr is None:
            # First join
            join_expr = ibis_tables[left_table].join(
                ibis_tables[right_table],
                ibis_tables[left_table][left_table_col] == ibis_tables[right_table][right_table_col],
                how='left'
            )
        else:
            # Subsequent joins using the previous join result
            join_expr = join_expr.join(
                ibis_tables[right_table],
                join_expr[left_table_col] == ibis_tables[right_table][right_table_col],
                how='left'
            )

    return join_expr

# Example usage:
# Test Case 5 with custom join order
json_data5 = {
  "nodes": [
    { "id": "1", "label": "Customer", "position": { "x": 100, "y": 100 } },
    { "id": "2", "label": "Invoice", "position": { "x": 300, "y": 100 } },
    { "id": "3", "label": "InvoiceLine", "position": { "x": 500, "y": 100 } },
    { "id": "4", "label": "Track", "position": { "x": 700, "y": 100 } },
    { "id": "5", "label": "Employee", "position": { "x": 900, "y": 100 } }
  ],
  "edges": [
    { "source": "1", "target": "2", "label": "Customer.CustomerId = Invoice.CustomerId" },
    { "source": "3", "target": "4", "label": "InvoiceLine.TrackId = Track.TrackId" },
    { "source": "2", "target": "3", "label": "Invoice.InvoiceId = InvoiceLine.InvoiceId" },
    { "source": "1", "target": "5", "label": "Customer.SupportRepId = Employee.EmployeeId" }
  ]
}


json_data = json_data5

# Convert GVQ to Ibis expression
ibis_expr = gvq_to_ibis(json_data)
print(ibis_expr)

# Execute the Ibis expression and fetch results
result = ibis_expr.execute()
result.info()
# Out:
# >>joins: [{'Customer.CustomerId': 'Invoice.CustomerId'}, {'InvoiceLine.TrackId': 'Track.TrackId'}, {'Invoice.InvoiceId': 'InvoiceLine.InvoiceId'}, {'Customer.SupportRepId': 'Employee.EmployeeId'}]
# >>sorted_joins: [{'Customer.SupportRepId': 'Employee.EmployeeId'}, {'Customer.CustomerId': 'Invoice.CustomerId'}, {'Invoice.InvoiceId': 'InvoiceLine.InvoiceId'}, {'InvoiceLine.TrackId': 'Track.TrackId'}]
# list_table: ['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track']
# Renamed columns for table Customer: ['Customer_CustomerId', 'Customer_FirstName', 'Customer_LastName', 'Customer_Company', 'Customer_Address', 'Customer_City', 'Customer_State', 'Customer_Country', 'Customer_PostalCode', 'Customer_Phone', 'Customer_Fax', 'Customer_Email', 'Customer_SupportRepId']
# Renamed columns for table Invoice: ['Invoice_InvoiceId', 'Invoice_CustomerId', 'Invoice_InvoiceDate', 'Invoice_BillingAddress', 'Invoice_BillingCity', 'Invoice_BillingState', 'Invoice_BillingCountry', 'Invoice_BillingPostalCode', 'Invoice_Total']
# Renamed columns for table InvoiceLine: ['InvoiceLine_InvoiceLineId', 'InvoiceLine_InvoiceId', 'InvoiceLine_TrackId', 'InvoiceLine_UnitPrice', 'InvoiceLine_Quantity']
# Renamed columns for table Track: ['Track_TrackId', 'Track_Name', 'Track_AlbumId', 'Track_MediaTypeId', 'Track_GenreId', 'Track_Composer', 'Track_Milliseconds', 'Track_Bytes', 'Track_UnitPrice']
# Renamed columns for table Employee: ['Employee_EmployeeId', 'Employee_LastName', 'Employee_FirstName', 'Employee_Title', 'Employee_ReportsTo', 'Employee_BirthDate', 'Employee_HireDate', 'Employee_Address', 'Employee_City', 'Employee_State', 'Employee_Country', 'Employee_PostalCode', 'Employee_Phone', 'Employee_Fax', 'Employee_Email']
# Updated join: {'Customer_SupportRepId': 'Employee_EmployeeId'}
# Updated join: {'Customer_CustomerId': 'Invoice_CustomerId'}
# Updated join: {'Invoice_InvoiceId': 'InvoiceLine_InvoiceId'}
# Updated join: {'InvoiceLine_TrackId': 'Track_TrackId'}
# r0 := DatabaseTable: Customer
#   CustomerId   int64
#   FirstName    string
#   LastName     string
#   Company      string
#   Address      string
#   City         string
#   State        string
#   Country      string
#   PostalCode   string
#   Phone        string
#   Fax          string
#   Email        string
#   SupportRepId int64
#
# r1 := DatabaseTable: Employee
#   EmployeeId int64
#   LastName   string
#   FirstName  string
#   Title      string
#   ReportsTo  int64
#   BirthDate  timestamp(6)
#   HireDate   timestamp(6)
#   Address    string
#   City       string
#   State      string
#   Country    string
#   PostalCode string
#   Phone      string
#   Fax        string
#   Email      string
#
# r2 := DatabaseTable: Invoice
#   InvoiceId         int64
#   CustomerId        int64
#   InvoiceDate       timestamp(6)
#   BillingAddress    string
#   BillingCity       string
#   BillingState      string
#   BillingCountry    string
#   BillingPostalCode string
#   Total             float64
#
# r3 := DatabaseTable: InvoiceLine
#   InvoiceLineId int64
#   InvoiceId     int64
#   TrackId       int64
#   UnitPrice     float64
#   Quantity      int64
#
# r4 := DatabaseTable: Track
#   TrackId      int64
#   Name         string
#   AlbumId      int64
#   MediaTypeId  int64
#   GenreId      int64
#   Composer     string
#   Milliseconds int64
#   Bytes        int64
#   UnitPrice    float64
#
# r5 := Project[r0]
#   Customer_CustomerId:   r0.CustomerId
#   Customer_FirstName:    r0.FirstName
#   Customer_LastName:     r0.LastName
#   Customer_Company:      r0.Company
#   Customer_Address:      r0.Address
#   Customer_City:         r0.City
#   Customer_State:        r0.State
#   Customer_Country:      r0.Country
#   Customer_PostalCode:   r0.PostalCode
#   Customer_Phone:        r0.Phone
#   Customer_Fax:          r0.Fax
#   Customer_Email:        r0.Email
#   Customer_SupportRepId: r0.SupportRepId
#
# r6 := Project[r1]
#   Employee_EmployeeId: r1.EmployeeId
#   Employee_LastName:   r1.LastName
#   Employee_FirstName:  r1.FirstName
#   Employee_Title:      r1.Title
#   Employee_ReportsTo:  r1.ReportsTo
#   Employee_BirthDate:  r1.BirthDate
#   Employee_HireDate:   r1.HireDate
#   Employee_Address:    r1.Address
#   Employee_City:       r1.City
#   Employee_State:      r1.State
#   Employee_Country:    r1.Country
#   Employee_PostalCode: r1.PostalCode
#   Employee_Phone:      r1.Phone
#   Employee_Fax:        r1.Fax
#   Employee_Email:      r1.Email
#
# r7 := Project[r2]
#   Invoice_InvoiceId:         r2.InvoiceId
#   Invoice_CustomerId:        r2.CustomerId
#   Invoice_InvoiceDate:       r2.InvoiceDate
#   Invoice_BillingAddress:    r2.BillingAddress
#   Invoice_BillingCity:       r2.BillingCity
#   Invoice_BillingState:      r2.BillingState
#   Invoice_BillingCountry:    r2.BillingCountry
#   Invoice_BillingPostalCode: r2.BillingPostalCode
#   Invoice_Total:             r2.Total
#
# r8 := Project[r3]
#   InvoiceLine_InvoiceLineId: r3.InvoiceLineId
#   InvoiceLine_InvoiceId:     r3.InvoiceId
#   InvoiceLine_TrackId:       r3.TrackId
#   InvoiceLine_UnitPrice:     r3.UnitPrice
#   InvoiceLine_Quantity:      r3.Quantity
#
# r9 := Project[r4]
#   Track_TrackId:      r4.TrackId
#   Track_Name:         r4.Name
#   Track_AlbumId:      r4.AlbumId
#   Track_MediaTypeId:  r4.MediaTypeId
#   Track_GenreId:      r4.GenreId
#   Track_Composer:     r4.Composer
#   Track_Milliseconds: r4.Milliseconds
#   Track_Bytes:        r4.Bytes
#   Track_UnitPrice:    r4.UnitPrice
#
# JoinChain[r5]
#   JoinLink[left, r6]
#     r5.Customer_SupportRepId == r6.Employee_EmployeeId
#   JoinLink[left, r7]
#     r5.Customer_CustomerId == r7.Invoice_CustomerId
#   JoinLink[left, r8]
#     r7.Invoice_InvoiceId == r8.InvoiceLine_InvoiceId
#   JoinLink[left, r9]
#     r8.InvoiceLine_TrackId == r9.Track_TrackId
#   values:
#     Customer_CustomerId:       r5.Customer_CustomerId
#     Customer_FirstName:        r5.Customer_FirstName
#     Customer_LastName:         r5.Customer_LastName
#     Customer_Company:          r5.Customer_Company
#     Customer_Address:          r5.Customer_Address
#     Customer_City:             r5.Customer_City
#     Customer_State:            r5.Customer_State
#     Customer_Country:          r5.Customer_Country
#     Customer_PostalCode:       r5.Customer_PostalCode
#     Customer_Phone:            r5.Customer_Phone
#     Customer_Fax:              r5.Customer_Fax
#     Customer_Email:            r5.Customer_Email
#     Customer_SupportRepId:     r5.Customer_SupportRepId
#     Employee_EmployeeId:       r6.Employee_EmployeeId
#     Employee_LastName:         r6.Employee_LastName
#     Employee_FirstName:        r6.Employee_FirstName
#     Employee_Title:            r6.Employee_Title
#     Employee_ReportsTo:        r6.Employee_ReportsTo
#     Employee_BirthDate:        r6.Employee_BirthDate
#     Employee_HireDate:         r6.Employee_HireDate
#     Employee_Address:          r6.Employee_Address
#     Employee_City:             r6.Employee_City
#     Employee_State:            r6.Employee_State
#     Employee_Country:          r6.Employee_Country
#     Employee_PostalCode:       r6.Employee_PostalCode
#     Employee_Phone:            r6.Employee_Phone
#     Employee_Fax:              r6.Employee_Fax
#     Employee_Email:            r6.Employee_Email
#     Invoice_InvoiceId:         r7.Invoice_InvoiceId
#     Invoice_CustomerId:        r7.Invoice_CustomerId
#     Invoice_InvoiceDate:       r7.Invoice_InvoiceDate
#     Invoice_BillingAddress:    r7.Invoice_BillingAddress
#     Invoice_BillingCity:       r7.Invoice_BillingCity
#     Invoice_BillingState:      r7.Invoice_BillingState
#     Invoice_BillingCountry:    r7.Invoice_BillingCountry
#     Invoice_BillingPostalCode: r7.Invoice_BillingPostalCode
#     Invoice_Total:             r7.Invoice_Total
#     InvoiceLine_InvoiceLineId: r8.InvoiceLine_InvoiceLineId
#     InvoiceLine_InvoiceId:     r8.InvoiceLine_InvoiceId
#     InvoiceLine_TrackId:       r8.InvoiceLine_TrackId
#     InvoiceLine_UnitPrice:     r8.InvoiceLine_UnitPrice
#     InvoiceLine_Quantity:      r8.InvoiceLine_Quantity
#     Track_TrackId:             r9.Track_TrackId
#     Track_Name:                r9.Track_Name
#     Track_AlbumId:             r9.Track_AlbumId
#     Track_MediaTypeId:         r9.Track_MediaTypeId
#     Track_GenreId:             r9.Track_GenreId
#     Track_Composer:            r9.Track_Composer
#     Track_Milliseconds:        r9.Track_Milliseconds
#     Track_Bytes:               r9.Track_Bytes
#     Track_UnitPrice:           r9.Track_UnitPrice
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 51 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer_CustomerId        2240 non-null   int64
#  1   Customer_FirstName         2240 non-null   object
#  2   Customer_LastName          2240 non-null   object
#  3   Customer_Company           380 non-null    object
#  4   Customer_Address           2240 non-null   object
#  5   Customer_City              2240 non-null   object
#  6   Customer_State             1140 non-null   object
#  7   Customer_Country           2240 non-null   object
#  8   Customer_PostalCode        2088 non-null   object
#  9   Customer_Phone             2202 non-null   object
#  10  Customer_Fax               456 non-null    object
#  11  Customer_Email             2240 non-null   object
#  12  Customer_SupportRepId      2240 non-null   int64
#  13  Employee_EmployeeId        2240 non-null   int64
#  14  Employee_LastName          2240 non-null   object
#  15  Employee_FirstName         2240 non-null   object
#  16  Employee_Title             2240 non-null   object
#  17  Employee_ReportsTo         2240 non-null   int64
#  18  Employee_BirthDate         2240 non-null   datetime64[ns]
#  19  Employee_HireDate          2240 non-null   datetime64[ns]
#  20  Employee_Address           2240 non-null   object
#  21  Employee_City              2240 non-null   object
#  22  Employee_State             2240 non-null   object
#  23  Employee_Country           2240 non-null   object
#  24  Employee_PostalCode        2240 non-null   object
#  25  Employee_Phone             2240 non-null   object
#  26  Employee_Fax               2240 non-null   object
#  27  Employee_Email             2240 non-null   object
#  28  Invoice_InvoiceId          2240 non-null   int64
#  29  Invoice_CustomerId         2240 non-null   int64
#  30  Invoice_InvoiceDate        2240 non-null   datetime64[ns]
#  31  Invoice_BillingAddress     2240 non-null   object
#  32  Invoice_BillingCity        2240 non-null   object
#  33  Invoice_BillingState       1140 non-null   object
#  34  Invoice_BillingCountry     2240 non-null   object
#  35  Invoice_BillingPostalCode  2088 non-null   object
#  36  Invoice_Total              2240 non-null   float64
#  37  InvoiceLine_InvoiceLineId  2240 non-null   int64
#  38  InvoiceLine_InvoiceId      2240 non-null   int64
#  39  InvoiceLine_TrackId        2240 non-null   int64
#  40  InvoiceLine_UnitPrice      2240 non-null   float64
#  41  InvoiceLine_Quantity       2240 non-null   int64
#  42  Track_TrackId              2240 non-null   int64
#  43  Track_Name                 2240 non-null   object
#  44  Track_AlbumId              2240 non-null   int64
#  45  Track_MediaTypeId          2240 non-null   int64
#  46  Track_GenreId              2240 non-null   int64
#  47  Track_Composer             1644 non-null   object
#  48  Track_Milliseconds         2240 non-null   int64
#  49  Track_Bytes                2240 non-null   int64
#  50  Track_UnitPrice            2240 non-null   float64
# dtypes: datetime64[ns](3), float64(3), int64(16), object(29)
# memory usage: 892.6+ KB

# %%
json_data6={
  "nodes": [
    { "id": "1", "label": "Customer", "position": { "x": 100, "y": 100 } },
    { "id": "2", "label": "Invoice", "position": { "x": 300, "y": 100 } },
    { "id": "3", "label": "InvoiceLine", "position": { "x": 500, "y": 100 } },
    { "id": "4", "label": "Track", "position": { "x": 700, "y": 100 } },
    { "id": "5", "label": "Album", "position": { "x": 900, "y": 100 } },
    { "id": "6", "label": "Artist", "position": { "x": 1100, "y": 100 } },
    { "id": "7", "label": "Genre", "position": { "x": 1300, "y": 100 } },
    { "id": "8", "label": "Employee", "position": { "x": 1500, "y": 100 } }
  ],
  "edges": [
    { "source": "1", "target": "2", "label": "Customer.CustomerId = Invoice.CustomerId" },
    { "source": "2", "target": "3", "label": "Invoice.InvoiceId = InvoiceLine.InvoiceId" },
    { "source": "3", "target": "4", "label": "InvoiceLine.TrackId = Track.TrackId" },
    { "source": "4", "target": "5", "label": "Track.AlbumId = Album.AlbumId" },
    { "source": "5", "target": "6", "label": "Album.ArtistId = Artist.ArtistId" },
    { "source": "4", "target": "7", "label": "Track.GenreId = Genre.GenreId" },
    { "source": "1", "target": "8", "label": "Customer.SupportRepId = Employee.EmployeeId" }
  ]
}



json_data = json_data6

# Convert GVQ to Ibis expression
ibis_expr = gvq_to_ibis(json_data)
print(ibis_expr)

# Execute the Ibis expression and fetch results
result = ibis_expr.execute()
result.info()
# Out:
# >>joins: [{'Customer.CustomerId': 'Invoice.CustomerId'}, {'Invoice.InvoiceId': 'InvoiceLine.InvoiceId'}, {'InvoiceLine.TrackId': 'Track.TrackId'}, {'Track.AlbumId': 'Album.AlbumId'}, {'Album.ArtistId': 'Artist.ArtistId'}, {'Track.GenreId': 'Genre.GenreId'}, {'Customer.SupportRepId': 'Employee.EmployeeId'}]
# >>sorted_joins: [{'Customer.SupportRepId': 'Employee.EmployeeId'}, {'Customer.CustomerId': 'Invoice.CustomerId'}, {'Invoice.InvoiceId': 'InvoiceLine.InvoiceId'}, {'InvoiceLine.TrackId': 'Track.TrackId'}, {'Track.AlbumId': 'Album.AlbumId'}, {'Track.GenreId': 'Genre.GenreId'}, {'Album.ArtistId': 'Artist.ArtistId'}]
# list_table: ['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track']
# Renamed columns for table Customer: ['Customer_CustomerId', 'Customer_FirstName', 'Customer_LastName', 'Customer_Company', 'Customer_Address', 'Customer_City', 'Customer_State', 'Customer_Country', 'Customer_PostalCode', 'Customer_Phone', 'Customer_Fax', 'Customer_Email', 'Customer_SupportRepId']
# Renamed columns for table Invoice: ['Invoice_InvoiceId', 'Invoice_CustomerId', 'Invoice_InvoiceDate', 'Invoice_BillingAddress', 'Invoice_BillingCity', 'Invoice_BillingState', 'Invoice_BillingCountry', 'Invoice_BillingPostalCode', 'Invoice_Total']
# Renamed columns for table InvoiceLine: ['InvoiceLine_InvoiceLineId', 'InvoiceLine_InvoiceId', 'InvoiceLine_TrackId', 'InvoiceLine_UnitPrice', 'InvoiceLine_Quantity']
# Renamed columns for table Track: ['Track_TrackId', 'Track_Name', 'Track_AlbumId', 'Track_MediaTypeId', 'Track_GenreId', 'Track_Composer', 'Track_Milliseconds', 'Track_Bytes', 'Track_UnitPrice']
# Renamed columns for table Album: ['Album_AlbumId', 'Album_Title', 'Album_ArtistId']
# Renamed columns for table Artist: ['Artist_ArtistId', 'Artist_Name']
# Renamed columns for table Genre: ['Genre_GenreId', 'Genre_Name']
# Renamed columns for table Employee: ['Employee_EmployeeId', 'Employee_LastName', 'Employee_FirstName', 'Employee_Title', 'Employee_ReportsTo', 'Employee_BirthDate', 'Employee_HireDate', 'Employee_Address', 'Employee_City', 'Employee_State', 'Employee_Country', 'Employee_PostalCode', 'Employee_Phone', 'Employee_Fax', 'Employee_Email']
# Updated join: {'Customer_SupportRepId': 'Employee_EmployeeId'}
# Updated join: {'Customer_CustomerId': 'Invoice_CustomerId'}
# Updated join: {'Invoice_InvoiceId': 'InvoiceLine_InvoiceId'}
# Updated join: {'InvoiceLine_TrackId': 'Track_TrackId'}
# Updated join: {'Track_AlbumId': 'Album_AlbumId'}
# Updated join: {'Track_GenreId': 'Genre_GenreId'}
# Updated join: {'Album_ArtistId': 'Artist_ArtistId'}
# r0 := DatabaseTable: Customer
#   CustomerId   int64
#   FirstName    string
#   LastName     string
#   Company      string
#   Address      string
#   City         string
#   State        string
#   Country      string
#   PostalCode   string
#   Phone        string
#   Fax          string
#   Email        string
#   SupportRepId int64
#
# r1 := DatabaseTable: Employee
#   EmployeeId int64
#   LastName   string
#   FirstName  string
#   Title      string
#   ReportsTo  int64
#   BirthDate  timestamp(6)
#   HireDate   timestamp(6)
#   Address    string
#   City       string
#   State      string
#   Country    string
#   PostalCode string
#   Phone      string
#   Fax        string
#   Email      string
#
# r2 := DatabaseTable: Invoice
#   InvoiceId         int64
#   CustomerId        int64
#   InvoiceDate       timestamp(6)
#   BillingAddress    string
#   BillingCity       string
#   BillingState      string
#   BillingCountry    string
#   BillingPostalCode string
#   Total             float64
#
# r3 := DatabaseTable: InvoiceLine
#   InvoiceLineId int64
#   InvoiceId     int64
#   TrackId       int64
#   UnitPrice     float64
#   Quantity      int64
#
# r4 := DatabaseTable: Track
#   TrackId      int64
#   Name         string
#   AlbumId      int64
#   MediaTypeId  int64
#   GenreId      int64
#   Composer     string
#   Milliseconds int64
#   Bytes        int64
#   UnitPrice    float64
#
# r5 := DatabaseTable: Album
#   AlbumId  int64
#   Title    string
#   ArtistId int64
#
# r6 := DatabaseTable: Genre
#   GenreId int64
#   Name    string
#
# r7 := DatabaseTable: Artist
#   ArtistId int64
#   Name     string
#
# r8 := Project[r0]
#   Customer_CustomerId:   r0.CustomerId
#   Customer_FirstName:    r0.FirstName
#   Customer_LastName:     r0.LastName
#   Customer_Company:      r0.Company
#   Customer_Address:      r0.Address
#   Customer_City:         r0.City
#   Customer_State:        r0.State
#   Customer_Country:      r0.Country
#   Customer_PostalCode:   r0.PostalCode
#   Customer_Phone:        r0.Phone
#   Customer_Fax:          r0.Fax
#   Customer_Email:        r0.Email
#   Customer_SupportRepId: r0.SupportRepId
#
# r9 := Project[r1]
#   Employee_EmployeeId: r1.EmployeeId
#   Employee_LastName:   r1.LastName
#   Employee_FirstName:  r1.FirstName
#   Employee_Title:      r1.Title
#   Employee_ReportsTo:  r1.ReportsTo
#   Employee_BirthDate:  r1.BirthDate
#   Employee_HireDate:   r1.HireDate
#   Employee_Address:    r1.Address
#   Employee_City:       r1.City
#   Employee_State:      r1.State
#   Employee_Country:    r1.Country
#   Employee_PostalCode: r1.PostalCode
#   Employee_Phone:      r1.Phone
#   Employee_Fax:        r1.Fax
#   Employee_Email:      r1.Email
#
# r10 := Project[r2]
#   Invoice_InvoiceId:         r2.InvoiceId
#   Invoice_CustomerId:        r2.CustomerId
#   Invoice_InvoiceDate:       r2.InvoiceDate
#   Invoice_BillingAddress:    r2.BillingAddress
#   Invoice_BillingCity:       r2.BillingCity
#   Invoice_BillingState:      r2.BillingState
#   Invoice_BillingCountry:    r2.BillingCountry
#   Invoice_BillingPostalCode: r2.BillingPostalCode
#   Invoice_Total:             r2.Total
#
# r11 := Project[r3]
#   InvoiceLine_InvoiceLineId: r3.InvoiceLineId
#   InvoiceLine_InvoiceId:     r3.InvoiceId
#   InvoiceLine_TrackId:       r3.TrackId
#   InvoiceLine_UnitPrice:     r3.UnitPrice
#   InvoiceLine_Quantity:      r3.Quantity
#
# r12 := Project[r4]
#   Track_TrackId:      r4.TrackId
#   Track_Name:         r4.Name
#   Track_AlbumId:      r4.AlbumId
#   Track_MediaTypeId:  r4.MediaTypeId
#   Track_GenreId:      r4.GenreId
#   Track_Composer:     r4.Composer
#   Track_Milliseconds: r4.Milliseconds
#   Track_Bytes:        r4.Bytes
#   Track_UnitPrice:    r4.UnitPrice
#
# r13 := Project[r5]
#   Album_AlbumId:  r5.AlbumId
#   Album_Title:    r5.Title
#   Album_ArtistId: r5.ArtistId
#
# r14 := Project[r6]
#   Genre_GenreId: r6.GenreId
#   Genre_Name:    r6.Name
#
# r15 := Project[r7]
#   Artist_ArtistId: r7.ArtistId
#   Artist_Name:     r7.Name
#
# JoinChain[r8]
#   JoinLink[left, r9]
#     r8.Customer_SupportRepId == r9.Employee_EmployeeId
#   JoinLink[left, r10]
#     r8.Customer_CustomerId == r10.Invoice_CustomerId
#   JoinLink[left, r11]
#     r10.Invoice_InvoiceId == r11.InvoiceLine_InvoiceId
#   JoinLink[left, r12]
#     r11.InvoiceLine_TrackId == r12.Track_TrackId
#   JoinLink[left, r13]
#     r12.Track_AlbumId == r13.Album_AlbumId
#   JoinLink[left, r14]
#     r12.Track_GenreId == r14.Genre_GenreId
#   JoinLink[left, r15]
#     r13.Album_ArtistId == r15.Artist_ArtistId
#   values:
#     Customer_CustomerId:       r8.Customer_CustomerId
#     Customer_FirstName:        r8.Customer_FirstName
#     Customer_LastName:         r8.Customer_LastName
#     Customer_Company:          r8.Customer_Company
#     Customer_Address:          r8.Customer_Address
#     Customer_City:             r8.Customer_City
#     Customer_State:            r8.Customer_State
#     Customer_Country:          r8.Customer_Country
#     Customer_PostalCode:       r8.Customer_PostalCode
#     Customer_Phone:            r8.Customer_Phone
#     Customer_Fax:              r8.Customer_Fax
#     Customer_Email:            r8.Customer_Email
#     Customer_SupportRepId:     r8.Customer_SupportRepId
#     Employee_EmployeeId:       r9.Employee_EmployeeId
#     Employee_LastName:         r9.Employee_LastName
#     Employee_FirstName:        r9.Employee_FirstName
#     Employee_Title:            r9.Employee_Title
#     Employee_ReportsTo:        r9.Employee_ReportsTo
#     Employee_BirthDate:        r9.Employee_BirthDate
#     Employee_HireDate:         r9.Employee_HireDate
#     Employee_Address:          r9.Employee_Address
#     Employee_City:             r9.Employee_City
#     Employee_State:            r9.Employee_State
#     Employee_Country:          r9.Employee_Country
#     Employee_PostalCode:       r9.Employee_PostalCode
#     Employee_Phone:            r9.Employee_Phone
#     Employee_Fax:              r9.Employee_Fax
#     Employee_Email:            r9.Employee_Email
#     Invoice_InvoiceId:         r10.Invoice_InvoiceId
#     Invoice_CustomerId:        r10.Invoice_CustomerId
#     Invoice_InvoiceDate:       r10.Invoice_InvoiceDate
#     Invoice_BillingAddress:    r10.Invoice_BillingAddress
#     Invoice_BillingCity:       r10.Invoice_BillingCity
#     Invoice_BillingState:      r10.Invoice_BillingState
#     Invoice_BillingCountry:    r10.Invoice_BillingCountry
#     Invoice_BillingPostalCode: r10.Invoice_BillingPostalCode
#     Invoice_Total:             r10.Invoice_Total
#     InvoiceLine_InvoiceLineId: r11.InvoiceLine_InvoiceLineId
#     InvoiceLine_InvoiceId:     r11.InvoiceLine_InvoiceId
#     InvoiceLine_TrackId:       r11.InvoiceLine_TrackId
#     InvoiceLine_UnitPrice:     r11.InvoiceLine_UnitPrice
#     InvoiceLine_Quantity:      r11.InvoiceLine_Quantity
#     Track_TrackId:             r12.Track_TrackId
#     Track_Name:                r12.Track_Name
#     Track_AlbumId:             r12.Track_AlbumId
#     Track_MediaTypeId:         r12.Track_MediaTypeId
#     Track_GenreId:             r12.Track_GenreId
#     Track_Composer:            r12.Track_Composer
#     Track_Milliseconds:        r12.Track_Milliseconds
#     Track_Bytes:               r12.Track_Bytes
#     Track_UnitPrice:           r12.Track_UnitPrice
#     Album_AlbumId:             r13.Album_AlbumId
#     Album_Title:               r13.Album_Title
#     Album_ArtistId:            r13.Album_ArtistId
#     Genre_GenreId:             r14.Genre_GenreId
#     Genre_Name:                r14.Genre_Name
#     Artist_ArtistId:           r15.Artist_ArtistId
#     Artist_Name:               r15.Artist_Name
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 58 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer_CustomerId        2240 non-null   int64
#  1   Customer_FirstName         2240 non-null   object
#  2   Customer_LastName          2240 non-null   object
#  3   Customer_Company           380 non-null    object
#  4   Customer_Address           2240 non-null   object
#  5   Customer_City              2240 non-null   object
#  6   Customer_State             1140 non-null   object
#  7   Customer_Country           2240 non-null   object
#  8   Customer_PostalCode        2088 non-null   object
#  9   Customer_Phone             2202 non-null   object
#  10  Customer_Fax               456 non-null    object
#  11  Customer_Email             2240 non-null   object
#  12  Customer_SupportRepId      2240 non-null   int64
#  13  Employee_EmployeeId        2240 non-null   int64
#  14  Employee_LastName          2240 non-null   object
#  15  Employee_FirstName         2240 non-null   object
#  16  Employee_Title             2240 non-null   object
#  17  Employee_ReportsTo         2240 non-null   int64
#  18  Employee_BirthDate         2240 non-null   datetime64[ns]
#  19  Employee_HireDate          2240 non-null   datetime64[ns]
#  20  Employee_Address           2240 non-null   object
#  21  Employee_City              2240 non-null   object
#  22  Employee_State             2240 non-null   object
#  23  Employee_Country           2240 non-null   object
#  24  Employee_PostalCode        2240 non-null   object
#  25  Employee_Phone             2240 non-null   object
#  26  Employee_Fax               2240 non-null   object
#  27  Employee_Email             2240 non-null   object
#  28  Invoice_InvoiceId          2240 non-null   int64
#  29  Invoice_CustomerId         2240 non-null   int64
#  30  Invoice_InvoiceDate        2240 non-null   datetime64[ns]
#  31  Invoice_BillingAddress     2240 non-null   object
#  32  Invoice_BillingCity        2240 non-null   object
#  33  Invoice_BillingState       1140 non-null   object
#  34  Invoice_BillingCountry     2240 non-null   object
#  35  Invoice_BillingPostalCode  2088 non-null   object
#  36  Invoice_Total              2240 non-null   float64
#  37  InvoiceLine_InvoiceLineId  2240 non-null   int64
#  38  InvoiceLine_InvoiceId      2240 non-null   int64
#  39  InvoiceLine_TrackId        2240 non-null   int64
#  40  InvoiceLine_UnitPrice      2240 non-null   float64
#  41  InvoiceLine_Quantity       2240 non-null   int64
#  42  Track_TrackId              2240 non-null   int64
#  43  Track_Name                 2240 non-null   object
#  44  Track_AlbumId              2240 non-null   int64
#  45  Track_MediaTypeId          2240 non-null   int64
#  46  Track_GenreId              2240 non-null   int64
#  47  Track_Composer             1644 non-null   object
#  48  Track_Milliseconds         2240 non-null   int64
#  49  Track_Bytes                2240 non-null   int64
#  50  Track_UnitPrice            2240 non-null   float64
#  51  Album_AlbumId              2240 non-null   int64
#  52  Album_Title                2240 non-null   object
#  53  Album_ArtistId             2240 non-null   int64
#  54  Genre_GenreId              2240 non-null   int64
#  55  Genre_Name                 2240 non-null   object
#  56  Artist_ArtistId            2240 non-null   int64
#  57  Artist_Name                2240 non-null   object
# dtypes: datetime64[ns](3), float64(3), int64(20), object(32)
# memory usage: 1015.1+ KB

# %%
json_data7 = {
  "nodes": [
    { "id": "1", "label": "Playlist", "position": { "x": 100, "y": 100 } },
    { "id": "2", "label": "PlaylistTrack", "position": { "x": 300, "y": 100 } },
    { "id": "3", "label": "Track", "position": { "x": 500, "y": 100 } },
    { "id": "4", "label": "Album", "position": { "x": 700, "y": 100 } },
    { "id": "5", "label": "Artist", "position": { "x": 900, "y": 100 } },
    { "id": "6", "label": "Genre", "position": { "x": 1100, "y": 100 } },
    { "id": "7", "label": "MediaType", "position": { "x": 1300, "y": 100 } },
    { "id": "8", "label": "Customer", "position": { "x": 1500, "y": 100 } },
    { "id": "9", "label": "Invoice", "position": { "x": 1700, "y": 100 } },
    { "id": "10", "label": "InvoiceLine", "position": { "x": 1900, "y": 100 } }
  ],
  "edges": [
    # { "source": "1", "target": "2", "label": "Playlist.PlaylistId = PlaylistTrack.PlaylistId" },
    # { "source": "2", "target": "3", "label": "PlaylistTrack.TrackId = Track.TrackId" },
    { "source": "3", "target": "4", "label": "Track.AlbumId = Album.AlbumId" },
    { "source": "4", "target": "5", "label": "Album.ArtistId = Artist.ArtistId" },
    { "source": "3", "target": "6", "label": "Track.GenreId = Genre.GenreId" },
    { "source": "3", "target": "7", "label": "Track.MediaTypeId = MediaType.MediaTypeId" },
    { "source": "8", "target": "9", "label": "Customer.CustomerId = Invoice.CustomerId" },
    { "source": "9", "target": "10", "label": "Invoice.InvoiceId = InvoiceLine.InvoiceId" },
    { "source": "10", "target": "3", "label": "InvoiceLine.TrackId = Track.TrackId" }
  ]
}


json_data = json_data7

# Convert GVQ to Ibis expression
ibis_expr = gvq_to_ibis(json_data)
print(ibis_expr)

# Execute the Ibis expression and fetch results
result = ibis_expr.execute()
result.info()
# Out:
# >>joins: [{'Track.AlbumId': 'Album.AlbumId'}, {'Album.ArtistId': 'Artist.ArtistId'}, {'Track.GenreId': 'Genre.GenreId'}, {'Track.MediaTypeId': 'MediaType.MediaTypeId'}, {'Customer.CustomerId': 'Invoice.CustomerId'}, {'Invoice.InvoiceId': 'InvoiceLine.InvoiceId'}, {'InvoiceLine.TrackId': 'Track.TrackId'}]
# >>sorted_joins: [{'Customer.CustomerId': 'Invoice.CustomerId'}, {'Invoice.InvoiceId': 'InvoiceLine.InvoiceId'}, {'InvoiceLine.TrackId': 'Track.TrackId'}, {'Track.AlbumId': 'Album.AlbumId'}, {'Track.GenreId': 'Genre.GenreId'}, {'Track.MediaTypeId': 'MediaType.MediaTypeId'}, {'Album.ArtistId': 'Artist.ArtistId'}]
# list_table: ['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track']
# Renamed columns for table Playlist: ['Playlist_PlaylistId', 'Playlist_Name']
# Renamed columns for table PlaylistTrack: ['PlaylistTrack_PlaylistId', 'PlaylistTrack_TrackId']
# Renamed columns for table Track: ['Track_TrackId', 'Track_Name', 'Track_AlbumId', 'Track_MediaTypeId', 'Track_GenreId', 'Track_Composer', 'Track_Milliseconds', 'Track_Bytes', 'Track_UnitPrice']
# Renamed columns for table Album: ['Album_AlbumId', 'Album_Title', 'Album_ArtistId']
# Renamed columns for table Artist: ['Artist_ArtistId', 'Artist_Name']
# Renamed columns for table Genre: ['Genre_GenreId', 'Genre_Name']
# Renamed columns for table MediaType: ['MediaType_MediaTypeId', 'MediaType_Name']
# Renamed columns for table Customer: ['Customer_CustomerId', 'Customer_FirstName', 'Customer_LastName', 'Customer_Company', 'Customer_Address', 'Customer_City', 'Customer_State', 'Customer_Country', 'Customer_PostalCode', 'Customer_Phone', 'Customer_Fax', 'Customer_Email', 'Customer_SupportRepId']
# Renamed columns for table Invoice: ['Invoice_InvoiceId', 'Invoice_CustomerId', 'Invoice_InvoiceDate', 'Invoice_BillingAddress', 'Invoice_BillingCity', 'Invoice_BillingState', 'Invoice_BillingCountry', 'Invoice_BillingPostalCode', 'Invoice_Total']
# Renamed columns for table InvoiceLine: ['InvoiceLine_InvoiceLineId', 'InvoiceLine_InvoiceId', 'InvoiceLine_TrackId', 'InvoiceLine_UnitPrice', 'InvoiceLine_Quantity']
# Updated join: {'Customer_CustomerId': 'Invoice_CustomerId'}
# Updated join: {'Invoice_InvoiceId': 'InvoiceLine_InvoiceId'}
# Updated join: {'InvoiceLine_TrackId': 'Track_TrackId'}
# Updated join: {'Track_AlbumId': 'Album_AlbumId'}
# Updated join: {'Track_GenreId': 'Genre_GenreId'}
# Updated join: {'Track_MediaTypeId': 'MediaType_MediaTypeId'}
# Updated join: {'Album_ArtistId': 'Artist_ArtistId'}
# r0 := DatabaseTable: Customer
#   CustomerId   int64
#   FirstName    string
#   LastName     string
#   Company      string
#   Address      string
#   City         string
#   State        string
#   Country      string
#   PostalCode   string
#   Phone        string
#   Fax          string
#   Email        string
#   SupportRepId int64
#
# r1 := DatabaseTable: Invoice
#   InvoiceId         int64
#   CustomerId        int64
#   InvoiceDate       timestamp(6)
#   BillingAddress    string
#   BillingCity       string
#   BillingState      string
#   BillingCountry    string
#   BillingPostalCode string
#   Total             float64
#
# r2 := DatabaseTable: InvoiceLine
#   InvoiceLineId int64
#   InvoiceId     int64
#   TrackId       int64
#   UnitPrice     float64
#   Quantity      int64
#
# r3 := DatabaseTable: Track
#   TrackId      int64
#   Name         string
#   AlbumId      int64
#   MediaTypeId  int64
#   GenreId      int64
#   Composer     string
#   Milliseconds int64
#   Bytes        int64
#   UnitPrice    float64
#
# r4 := DatabaseTable: Album
#   AlbumId  int64
#   Title    string
#   ArtistId int64
#
# r5 := DatabaseTable: Genre
#   GenreId int64
#   Name    string
#
# r6 := DatabaseTable: MediaType
#   MediaTypeId int64
#   Name        string
#
# r7 := DatabaseTable: Artist
#   ArtistId int64
#   Name     string
#
# r8 := Project[r0]
#   Customer_CustomerId:   r0.CustomerId
#   Customer_FirstName:    r0.FirstName
#   Customer_LastName:     r0.LastName
#   Customer_Company:      r0.Company
#   Customer_Address:      r0.Address
#   Customer_City:         r0.City
#   Customer_State:        r0.State
#   Customer_Country:      r0.Country
#   Customer_PostalCode:   r0.PostalCode
#   Customer_Phone:        r0.Phone
#   Customer_Fax:          r0.Fax
#   Customer_Email:        r0.Email
#   Customer_SupportRepId: r0.SupportRepId
#
# r9 := Project[r1]
#   Invoice_InvoiceId:         r1.InvoiceId
#   Invoice_CustomerId:        r1.CustomerId
#   Invoice_InvoiceDate:       r1.InvoiceDate
#   Invoice_BillingAddress:    r1.BillingAddress
#   Invoice_BillingCity:       r1.BillingCity
#   Invoice_BillingState:      r1.BillingState
#   Invoice_BillingCountry:    r1.BillingCountry
#   Invoice_BillingPostalCode: r1.BillingPostalCode
#   Invoice_Total:             r1.Total
#
# r10 := Project[r2]
#   InvoiceLine_InvoiceLineId: r2.InvoiceLineId
#   InvoiceLine_InvoiceId:     r2.InvoiceId
#   InvoiceLine_TrackId:       r2.TrackId
#   InvoiceLine_UnitPrice:     r2.UnitPrice
#   InvoiceLine_Quantity:      r2.Quantity
#
# r11 := Project[r3]
#   Track_TrackId:      r3.TrackId
#   Track_Name:         r3.Name
#   Track_AlbumId:      r3.AlbumId
#   Track_MediaTypeId:  r3.MediaTypeId
#   Track_GenreId:      r3.GenreId
#   Track_Composer:     r3.Composer
#   Track_Milliseconds: r3.Milliseconds
#   Track_Bytes:        r3.Bytes
#   Track_UnitPrice:    r3.UnitPrice
#
# r12 := Project[r4]
#   Album_AlbumId:  r4.AlbumId
#   Album_Title:    r4.Title
#   Album_ArtistId: r4.ArtistId
#
# r13 := Project[r5]
#   Genre_GenreId: r5.GenreId
#   Genre_Name:    r5.Name
#
# r14 := Project[r6]
#   MediaType_MediaTypeId: r6.MediaTypeId
#   MediaType_Name:        r6.Name
#
# r15 := Project[r7]
#   Artist_ArtistId: r7.ArtistId
#   Artist_Name:     r7.Name
#
# JoinChain[r8]
#   JoinLink[left, r9]
#     r8.Customer_CustomerId == r9.Invoice_CustomerId
#   JoinLink[left, r10]
#     r9.Invoice_InvoiceId == r10.InvoiceLine_InvoiceId
#   JoinLink[left, r11]
#     r10.InvoiceLine_TrackId == r11.Track_TrackId
#   JoinLink[left, r12]
#     r11.Track_AlbumId == r12.Album_AlbumId
#   JoinLink[left, r13]
#     r11.Track_GenreId == r13.Genre_GenreId
#   JoinLink[left, r14]
#     r11.Track_MediaTypeId == r14.MediaType_MediaTypeId
#   JoinLink[left, r15]
#     r12.Album_ArtistId == r15.Artist_ArtistId
#   values:
#     Customer_CustomerId:       r8.Customer_CustomerId
#     Customer_FirstName:        r8.Customer_FirstName
#     Customer_LastName:         r8.Customer_LastName
#     Customer_Company:          r8.Customer_Company
#     Customer_Address:          r8.Customer_Address
#     Customer_City:             r8.Customer_City
#     Customer_State:            r8.Customer_State
#     Customer_Country:          r8.Customer_Country
#     Customer_PostalCode:       r8.Customer_PostalCode
#     Customer_Phone:            r8.Customer_Phone
#     Customer_Fax:              r8.Customer_Fax
#     Customer_Email:            r8.Customer_Email
#     Customer_SupportRepId:     r8.Customer_SupportRepId
#     Invoice_InvoiceId:         r9.Invoice_InvoiceId
#     Invoice_CustomerId:        r9.Invoice_CustomerId
#     Invoice_InvoiceDate:       r9.Invoice_InvoiceDate
#     Invoice_BillingAddress:    r9.Invoice_BillingAddress
#     Invoice_BillingCity:       r9.Invoice_BillingCity
#     Invoice_BillingState:      r9.Invoice_BillingState
#     Invoice_BillingCountry:    r9.Invoice_BillingCountry
#     Invoice_BillingPostalCode: r9.Invoice_BillingPostalCode
#     Invoice_Total:             r9.Invoice_Total
#     InvoiceLine_InvoiceLineId: r10.InvoiceLine_InvoiceLineId
#     InvoiceLine_InvoiceId:     r10.InvoiceLine_InvoiceId
#     InvoiceLine_TrackId:       r10.InvoiceLine_TrackId
#     InvoiceLine_UnitPrice:     r10.InvoiceLine_UnitPrice
#     InvoiceLine_Quantity:      r10.InvoiceLine_Quantity
#     Track_TrackId:             r11.Track_TrackId
#     Track_Name:                r11.Track_Name
#     Track_AlbumId:             r11.Track_AlbumId
#     Track_MediaTypeId:         r11.Track_MediaTypeId
#     Track_GenreId:             r11.Track_GenreId
#     Track_Composer:            r11.Track_Composer
#     Track_Milliseconds:        r11.Track_Milliseconds
#     Track_Bytes:               r11.Track_Bytes
#     Track_UnitPrice:           r11.Track_UnitPrice
#     Album_AlbumId:             r12.Album_AlbumId
#     Album_Title:               r12.Album_Title
#     Album_ArtistId:            r12.Album_ArtistId
#     Genre_GenreId:             r13.Genre_GenreId
#     Genre_Name:                r13.Genre_Name
#     MediaType_MediaTypeId:     r14.MediaType_MediaTypeId
#     MediaType_Name:            r14.MediaType_Name
#     Artist_ArtistId:           r15.Artist_ArtistId
#     Artist_Name:               r15.Artist_Name
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 45 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer_CustomerId        2240 non-null   int64
#  1   Customer_FirstName         2240 non-null   object
#  2   Customer_LastName          2240 non-null   object
#  3   Customer_Company           380 non-null    object
#  4   Customer_Address           2240 non-null   object
#  5   Customer_City              2240 non-null   object
#  6   Customer_State             1140 non-null   object
#  7   Customer_Country           2240 non-null   object
#  8   Customer_PostalCode        2088 non-null   object
#  9   Customer_Phone             2202 non-null   object
#  10  Customer_Fax               456 non-null    object
#  11  Customer_Email             2240 non-null   object
#  12  Customer_SupportRepId      2240 non-null   int64
#  13  Invoice_InvoiceId          2240 non-null   int64
#  14  Invoice_CustomerId         2240 non-null   int64
#  15  Invoice_InvoiceDate        2240 non-null   datetime64[ns]
#  16  Invoice_BillingAddress     2240 non-null   object
#  17  Invoice_BillingCity        2240 non-null   object
#  18  Invoice_BillingState       1140 non-null   object
#  19  Invoice_BillingCountry     2240 non-null   object
#  20  Invoice_BillingPostalCode  2088 non-null   object
#  21  Invoice_Total              2240 non-null   float64
#  22  InvoiceLine_InvoiceLineId  2240 non-null   int64
#  23  InvoiceLine_InvoiceId      2240 non-null   int64
#  24  InvoiceLine_TrackId        2240 non-null   int64
#  25  InvoiceLine_UnitPrice      2240 non-null   float64
#  26  InvoiceLine_Quantity       2240 non-null   int64
#  27  Track_TrackId              2240 non-null   int64
#  28  Track_Name                 2240 non-null   object
#  29  Track_AlbumId              2240 non-null   int64
#  30  Track_MediaTypeId          2240 non-null   int64
#  31  Track_GenreId              2240 non-null   int64
#  32  Track_Composer             1644 non-null   object
#  33  Track_Milliseconds         2240 non-null   int64
#  34  Track_Bytes                2240 non-null   int64
#  35  Track_UnitPrice            2240 non-null   float64
#  36  Album_AlbumId              2240 non-null   int64
#  37  Album_Title                2240 non-null   object
#  38  Album_ArtistId             2240 non-null   int64
#  39  Genre_GenreId              2240 non-null   int64
#  40  Genre_Name                 2240 non-null   object
#  41  MediaType_MediaTypeId      2240 non-null   int64
#  42  MediaType_Name             2240 non-null   object
#  43  Artist_ArtistId            2240 non-null   int64
#  44  Artist_Name                2240 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(19), object(22)
# memory usage: 787.6+ KB
